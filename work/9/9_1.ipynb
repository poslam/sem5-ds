# %% [markdown]
# В этом занятии вам предстоит потренироваться построению нейронных сетей с помощью библиотеки Pytorch.

# %%
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torch.nn import functional as F

from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# # Часть 1. Датасет moons

# %%
X, y = make_moons(n_samples=10000, random_state=42, noise=0.1)
X
# Out:
# array([[ 0.45549318, -0.12550304],
#        [-0.70421731,  0.04130827],
#        [ 0.41379864,  0.79132194],
#        ...,
#        [-0.03803096,  0.24540791],
#        [ 0.8698024 ,  0.52329471],
#        [ 1.16429638, -0.3798397 ]])

# %%
plt.figure(figsize=(16, 10))
plt.title("Dataset")
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="viridis")
plt.show()

# %% [markdown]
# Сделаем train/test split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### Загрузка данных
# В PyTorch загрузка данных как правило происходит налету (иногда датасеты не помещаются в оперативную память). Для этого используются две сущности `Dataset` и `DataLoader`.
#
# 1.   `Dataset` загружает каждый объект по отдельности.
#
# 2.   `DataLoader` группирует объекты из `Dataset` в батчи.
#
# Так как наш датасет достаточно маленький мы будем использовать `TensorDataset`. Все, что нам нужно, это перевести из массива numpy в тензор с типом `torch.float32`.
#
# ### Задание. Создайте тензоры с обучающими и тестовыми данными

# %%
X_train_t = torch.from_numpy(X_train).to(torch.float32)
y_train_t = torch.from_numpy(y_train).to(torch.float32)
X_val_t = torch.from_numpy(X_val).to(torch.float32)
y_val_t = torch.from_numpy(y_val).to(torch.float32)

# %% [markdown]
# Создаем `Dataset` и `DataLoader`.

# %%
train_dataset = TensorDataset(X_train_t, y_train_t)
val_dataset = TensorDataset(X_val_t, y_val_t)
train_dataloader = DataLoader(train_dataset, batch_size=128)
val_dataloader = DataLoader(val_dataset, batch_size=128)

# %% [markdown]
# ## Logistic regression
#
# **Напоминание**
# На входе у нас есть матрица объект-признак X и столбец-вектор $y$ – метки из $\{0, 1\}$ для каждого объекта. Мы хотим найти такую матрицу весов $W$ и смещение $b$ (bias), что наша модель $XW + b$ будет каким-то образом предсказывать класс объекта. Как видно на выходе наша модель может выдавать число в интервале от $(-\infty;\infty)$. Этот выход как правило называют "логитами" (logits). Нам необходимо перевести его на интервал от $[0;1]$ для того, чтобы он выдавал нам вероятность принадлежности объекта к кассу один, также лучше, чтобы эта функция была монотонной, быстро считалась, имела производную и на $-\infty$ имела значение $0$, а на $+\infty$ имела значение $1$. Такой класс функций называется сигмоидыю. Чаще всего в качестве сигмоида берут
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}.
# $$

# %% [markdown]
# ### Задание. Реализация логистической регрессии
#
# Вам необходимо написать модуль на PyTorch реализующий $logits = XW + b$, где $W$ и $b$ – параметры (`nn.Parameter`) модели. Иначе говоря, здесь мы реализуем своими руками модуль `nn.Linear` (в этом пункте его использование запрещено). Инициализируйте веса нормальным распределением (`torch.randn`).

# %%
class LinearRegression(nn.Module):
    def __init__(self, in_features: int, out_features: int, bias: bool = True):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weights = nn.Parameter(torch.randn((in_features, out_features)))
        self.bias = bias
        if bias:
            self.bias_term = nn.Parameter(torch.randn(out_features))

    def forward(self, x):
        x = x @ self.weights
        if self.bias:
            x += self.bias_term
        return x

# %%
linear_regression = LinearRegression(2, 1)
loss_function = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(linear_regression.parameters(), lr=0.05)

# %% [markdown]
# **Вопрос 1.** Сколько обучаемых параметров у получившейся модели? Имеется в виду суммарное количество отдельных числовых переменных, а не количество тензоров.

# %%
linear_regression.in_features + 1  # + 1 для bias
# Out:
# 3

# %% [markdown]
# ### Train loop
#
# Вот псевдокод, который поможет вам разобраться в том, что происходит во время обучения
#
# ```python
# for epoch in range(max_epochs):  # <----------- итерируемся по датасету несколько раз
#     for x_batch, y_batch in dataset:  # <------ итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#         optimizer.zero_grad()  # <------------- обуляем градиенты модели
#         outp = model(x_batch)  # <------------- получаем "логиты" из модели
#         loss = loss_func(outp, y_batch)  # <--- считаем "лосс" для логистической регрессии
#         loss.backward()  # <------------------- считаем градиенты
#         optimizer.step()  # <------------------ делаем шаг градиентного спуска
#         if convergence:  # <------------------- в случае сходимости выходим из цикла
#             break
# ```
#
# В коде ниже добавлено логирование `accuracy` и `loss`.

# %% [markdown]
# ### Задание. Реализация цикла обучения

# %%
tol = 1e-20
losses = []
max_epochs = 100
prev_weights = torch.zeros_like(linear_regression.weights)
stop_it = False
for epoch in range(max_epochs):
    for it, (X_batch, y_batch) in enumerate(train_dataloader):
        optimizer.zero_grad()
        outp = linear_regression(X_batch)
        outp = outp.squeeze(1)
        loss = loss_function(outp, y_batch)
        loss.backward()
        losses.append(loss.detach().flatten()[0])
        optimizer.step()
        probabilities = torch.sigmoid(outp)
        preds = (probabilities > 0.5).type(torch.long)
        batch_acc = (preds.flatten() == y_batch).type(
            torch.float32
        ).sum() / y_batch.size(0)

        if (it + epoch * len(train_dataloader)) % 100 == 0:
            print(
                f"Iteration: {it + epoch * len(train_dataloader)}\nBatch accuracy: {batch_acc}"
            )
        current_weights = linear_regression.weights.detach().clone()
        if (prev_weights - current_weights).abs().max() < tol:
            print(
                f"\nIteration: {it + epoch * len(train_dataloader)}.Convergence. Stopping iterations."
            )
            stop_it = True
            break
        prev_weights = current_weights
    if stop_it:
        break
# Out:
# Iteration: 0
# Batch accuracy: 0.5234375
# Iteration: 100
# Batch accuracy: 0.8671875
# Iteration: 200
# Batch accuracy: 0.84375
# Iteration: 300
# Batch accuracy: 0.921875
# Iteration: 400
# Batch accuracy: 0.890625
# Iteration: 500
# Batch accuracy: 0.9140625
# Iteration: 600
# Batch accuracy: 0.8828125
# Iteration: 700
# Batch accuracy: 0.84375
# Iteration: 800
# Batch accuracy: 0.8671875
# Iteration: 900
# Batch accuracy: 0.8359375
# Iteration: 1000
# Batch accuracy: 0.8828125
# Iteration: 1100
# Batch accuracy: 0.875
# Iteration: 1200
# Batch accuracy: 0.90625
# Iteration: 1300
# Batch accuracy: 0.859375
# Iteration: 1400
# Batch accuracy: 0.9140625
# Iteration: 1500
# Batch accuracy: 0.828125
# Iteration: 1600
# Batch accuracy: 0.8359375
# Iteration: 1700
# Batch accuracy: 0.8984375
# Iteration: 1800
# Batch accuracy: 0.859375
# Iteration: 1900
# Batch accuracy: 0.8984375
# Iteration: 2000
# Batch accuracy: 0.859375
# Iteration: 2100
# Batch accuracy: 0.890625
# Iteration: 2200
# Batch accuracy: 0.890625
# Iteration: 2300
# Batch accuracy: 0.8947368264198303
# Iteration: 2400
# Batch accuracy: 0.875
# Iteration: 2500
# Batch accuracy: 0.875
# Iteration: 2600
# Batch accuracy: 0.90625
# Iteration: 2700
# Batch accuracy: 0.8359375
# Iteration: 2800
# Batch accuracy: 0.9140625
# Iteration: 2900
# Batch accuracy: 0.8515625
# Iteration: 3000
# Batch accuracy: 0.859375
# Iteration: 3100
# Batch accuracy: 0.9375
# Iteration: 3200
# Batch accuracy: 0.8984375
# Iteration: 3300
# Batch accuracy: 0.90625
# Iteration: 3400
# Batch accuracy: 0.8828125
# Iteration: 3500
# Batch accuracy: 0.953125
# Iteration: 3600
# Batch accuracy: 0.90625
# Iteration: 3700
# Batch accuracy: 0.875
# Iteration: 3800
# Batch accuracy: 0.9296875
# Iteration: 3900
# Batch accuracy: 0.859375
# Iteration: 4000
# Batch accuracy: 0.84375
# Iteration: 4100
# Batch accuracy: 0.8671875
# Iteration: 4200
# Batch accuracy: 0.875
# Iteration: 4300
# Batch accuracy: 0.9140625
# Iteration: 4400
# Batch accuracy: 0.921875
# Iteration: 4500
# Batch accuracy: 0.84375
# Iteration: 4600
# Batch accuracy: 0.90625
# Iteration: 4700
# Batch accuracy: 0.84375
# Iteration: 4800
# Batch accuracy: 0.8828125
# Iteration: 4900
# Batch accuracy: 0.875
# Iteration: 5000
# Batch accuracy: 0.8671875
# Iteration: 5100
# Batch accuracy: 0.8359375
# Iteration: 5200
# Batch accuracy: 0.84375
# Iteration: 5300
# Batch accuracy: 0.859375
# Iteration: 5400
# Batch accuracy: 0.890625
# Iteration: 5500
# Batch accuracy: 0.859375
# Iteration: 5600
# Batch accuracy: 0.8515625
# Iteration: 5700
# Batch accuracy: 0.84375
# Iteration: 5800
# Batch accuracy: 0.875

# %% [markdown]
# ### Визуализируем результаты

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(len(losses)), losses)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
import numpy as np

xx, yy = np.mgrid[-1.5:2.5:0.01, -1.0:1.5:0.01]
grid = np.c_[xx.ravel(), yy.ravel()]
batch = torch.from_numpy(grid).type(torch.float32)
with torch.no_grad():
    probs = torch.sigmoid(linear_regression(batch).reshape(xx.shape))
    probs = probs.numpy().reshape(xx.shape)

f, ax = plt.subplots(figsize=(16, 10))
ax.set_title("Decision boundary", fontsize=14)
contour = ax.contourf(xx, yy, probs, 25, cmap="RdBu", vmin=0, vmax=1)
ax_c = f.colorbar(contour)
ax_c.set_label("$P(y = 1)$")
ax_c.set_ticks([0, 0.25, 0.5, 0.75, 1])

ax.scatter(
    X[100:, 0],
    X[100:, 1],
    c=y[100:],
    s=50,
    cmap="RdBu",
    vmin=-0.2,
    vmax=1.2,
    edgecolor="white",
    linewidth=1,
)

ax.set(xlabel="$X_1$", ylabel="$X_2$")
plt.show()

# %% [markdown]
# ### Задание. Реализуйте predict и посчитайте accuracy на test.

# %%
@torch.no_grad()
def predict(dataloader, model):
    model.eval()
    predictions = np.array([])
    for x_batch, _ in dataloader:
        outp = model(x_batch)
        probabilities = torch.sigmoid(outp)
        preds = (probabilities > 0.5).type(torch.long)
        predictions = np.hstack((predictions, preds.numpy().flatten()))
    return predictions.flatten()

# %%
from sklearn.metrics import accuracy_score

preds = predict(val_dataloader, linear_regression)
accuracy_score(y_val_t.numpy(), preds)
# Out:
# 0.8936

# %% [markdown]
# **Вопрос 2**
#
# Какое `accuracy` получается после обучения?
#
# **Ответ:** 0.8936

# %% [markdown]
# # Часть 2. Датасет MNIST

# %%
import os
from torchvision.datasets import MNIST
from torchvision import transforms as tfs

data_tfs = tfs.Compose([tfs.ToTensor(), tfs.Normalize((0.5), (0.5))])

# install for train and test
root = "./"
train_dataset = MNIST(root, train=True, transform=data_tfs, download=True)
val_dataset = MNIST(root, train=False, transform=data_tfs, download=True)
print(type(val_dataset))

train_dataloader = DataLoader(train_dataset, batch_size=128)
valid_dataloader = DataLoader(val_dataset, batch_size=128)
# Out:
# <class 'torchvision.datasets.mnist.MNIST'>

# %%
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_dataset), size=(1,)).item()
    img, label = train_dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# ## Часть 2.1. Полносвязные нейронные сети

# %%
class Identical(nn.Module):
    def forward(self, x):
        return x

# %% [markdown]
# ### Задание. Простая полносвязная нейронная сеть
#
# Создайте полносвязную нейронную сеть с помощью класса Sequential. Сеть состоит из:
# * Уплощения матрицы в вектор (nn.Flatten);
# * Двух скрытых слоёв из 128 нейронов с активацией nn.ELU;
# * Выходного слоя с 10 нейронами.
#
# Задайте лосс для обучения (кросс-энтропия).

# %%
activation = nn.ELU()

model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 128),
    activation,
    nn.Linear(128, 128),
    activation,
    nn.Linear(128, 10),
)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ### Train loop (seriously)
#
#
#
# ```python
# for epoch in range(max_epochs):  # <--------------- итерируемся по датасету несколько раз
#     for k, dataloader in loaders.items():  # <----- несколько dataloader для train / valid / test
#         for x_batch, y_batch in dataloader:  # <--- итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#             if k == "train":
#                 model.train()  # <------------------ переводим модель в режим train
#                 optimizer.zero_grad()  # <--------- обнуляем градиенты модели
#                 outp = model(x_batch)
#                 loss = criterion(outp, y_batch) # <-считаем "лосс" для логистической регрессии
#                 loss.backward()  # <--------------- считаем градиенты
#                 optimizer.step()  # <-------------- делаем шаг градиентного спуска
#             else:  # <----------------------------- test/eval
#                 model.eval()  # <------------------ переводим модель в режим eval
#                 with torch.no_grad():  # <--------- НЕ считаем градиенты
#                     outp = model(x_batch)  # <------------- получаем "логиты" из модели
#             count_metrics(outp, y_batch)  # <-------------- считаем метрики
# ```

# %% [markdown]
# ### Задание. Дополните цикл обучения.

# %%
max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in range(max_epochs):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0

        for x_batch, y_batch in dataloader:
            if k == "train":
                model.train()
                optimizer.zero_grad()
                outp = model(x_batch)
                loss = criterion(outp, y_batch)
                loss.backward()
                optimizer.step()

            else:
                model.eval()
                with torch.no_grad():
                    outp = model(x_batch)

            preds = outp.argmax(-1)
            correct = (preds == y_batch).sum()
            all = len(y_batch)
            epoch_correct += correct.item()
            epoch_all += all

        if k == "train":
            print(f"Epoch: {epoch + 1}")

        print(f"Loader: {k}. Accuracy: {epoch_correct / epoch_all}")
        accuracy[k].append(epoch_correct / epoch_all)
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.8802833333333333
# Loader: valid. Accuracy: 0.922
# Epoch: 2
# Loader: train. Accuracy: 0.9411
# Loader: valid. Accuracy: 0.9498
# Epoch: 3
# Loader: train. Accuracy: 0.95905
# Loader: valid. Accuracy: 0.9549
# Epoch: 4
# Loader: train. Accuracy: 0.96725
# Loader: valid. Accuracy: 0.9589
# Epoch: 5
# Loader: train. Accuracy: 0.9736833333333333
# Loader: valid. Accuracy: 0.9604
# Epoch: 6
# Loader: train. Accuracy: 0.9778166666666667
# Loader: valid. Accuracy: 0.965
# Epoch: 7
# Loader: train. Accuracy: 0.98085
# Loader: valid. Accuracy: 0.967
# Epoch: 8
# Loader: train. Accuracy: 0.9835
# Loader: valid. Accuracy: 0.9702
# Epoch: 9
# Loader: train. Accuracy: 0.9856166666666667
# Loader: valid. Accuracy: 0.9659
# Epoch: 10
# Loader: train. Accuracy: 0.9864833333333334
# Loader: valid. Accuracy: 0.9681

# %% [markdown]
# ### Задание. Протестируйте разные функции активации.
# Попробуйте разные функции активации. Для каждой функции активации посчитайте массив validation accuracy. Лучше реализовать это в виде функции, берущей на вход активацию и получающей массив из accuracies.

# %%
elu_accuracy = accuracy["valid"]

# %%
def test_activation_function(activation):
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(784, 128),
        activation,
        nn.Linear(128, 128),
        activation,
        nn.Linear(128, 10),
    )
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters())

    accuracy = {"train": [], "valid": []}
    max_epochs = 10

    for epoch in range(max_epochs):
        for k, dataloader in loaders.items():
            epoch_correct = 0
            epoch_all = 0
            for x_batch, y_batch in dataloader:
                if k == "train":
                    model.train()
                    optimizer.zero_grad()
                    outp = model(x_batch)
                    loss = criterion(outp, y_batch)
                    loss.backward()
                    optimizer.step()
                else:
                    model.eval()
                    with torch.no_grad():
                        outp = model(x_batch)

                preds = outp.argmax(-1)
                correct = (preds == y_batch).sum()
                all = len(y_batch)
                epoch_correct += correct.item()
                epoch_all += all

            if k == "train":
                print(f"Epoch: {epoch + 1}")
            print(
                f"Activation: {activation}. Loader: {k}. Accuracy: {epoch_correct / epoch_all}"
            )

            accuracy[k].append(epoch_correct / epoch_all)
    return accuracy["valid"]

# %%
plain_accuracy = test_activation_function(Identical())
relu_accuracy = test_activation_function(nn.ReLU())
leaky_relu_accuracy = test_activation_function(nn.LeakyReLU())
tanh_accuracy = test_activation_function(nn.Tanh())
print(plain_accuracy, relu_accuracy, leaky_relu_accuracy, tanh_accuracy)
# Out:
# Epoch: 1
# Activation: Identical(). Loader: train. Accuracy: 0.8643333333333333
# Activation: Identical(). Loader: valid. Accuracy: 0.8854
# Epoch: 2
# Activation: Identical(). Loader: train. Accuracy: 0.8952
# Activation: Identical(). Loader: valid. Accuracy: 0.8998
# Epoch: 3
# Activation: Identical(). Loader: train. Accuracy: 0.9004166666666666
# Activation: Identical(). Loader: valid. Accuracy: 0.9008
# Epoch: 4
# Activation: Identical(). Loader: train. Accuracy: 0.9027166666666666
# Activation: Identical(). Loader: valid. Accuracy: 0.9018
# Epoch: 5
# Activation: Identical(). Loader: train. Accuracy: 0.9043833333333333
# Activation: Identical(). Loader: valid. Accuracy: 0.9014
# Epoch: 6
# Activation: Identical(). Loader: train. Accuracy: 0.9056833333333333
# Activation: Identical(). Loader: valid. Accuracy: 0.9012
# Epoch: 7
# Activation: Identical(). Loader: train. Accuracy: 0.9067833333333334
# Activation: Identical(). Loader: valid. Accuracy: 0.901
# Epoch: 8
# Activation: Identical(). Loader: train. Accuracy: 0.9080166666666667
# Activation: Identical(). Loader: valid. Accuracy: 0.9014
# Epoch: 9
# Activation: Identical(). Loader: train. Accuracy: 0.9089833333333334
# Activation: Identical(). Loader: valid. Accuracy: 0.902
# Epoch: 10
# Activation: Identical(). Loader: train. Accuracy: 0.90985
# Activation: Identical(). Loader: valid. Accuracy: 0.9034
# Epoch: 1
# Activation: ReLU(). Loader: train. Accuracy: 0.86965
# Activation: ReLU(). Loader: valid. Accuracy: 0.9251
# Epoch: 2
# Activation: ReLU(). Loader: train. Accuracy: 0.9324
# Activation: ReLU(). Loader: valid. Accuracy: 0.9472
# Epoch: 3
# Activation: ReLU(). Loader: train. Accuracy: 0.9524666666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.958
# Epoch: 4
# Activation: ReLU(). Loader: train. Accuracy: 0.9625666666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.9612
# Epoch: 5
# Activation: ReLU(). Loader: train. Accuracy: 0.969
# Activation: ReLU(). Loader: valid. Accuracy: 0.9642
# Epoch: 6
# Activation: ReLU(). Loader: train. Accuracy: 0.9745
# Activation: ReLU(). Loader: valid. Accuracy: 0.9661
# Epoch: 7
# Activation: ReLU(). Loader: train. Accuracy: 0.9770666666666666
# Activation: ReLU(). Loader: valid. Accuracy: 0.9672
# Epoch: 8
# Activation: ReLU(). Loader: train. Accuracy: 0.9796166666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.9665
# Epoch: 9
# Activation: ReLU(). Loader: train. Accuracy: 0.9817166666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.9664
# Epoch: 10
# Activation: ReLU(). Loader: train. Accuracy: 0.9836166666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.9675
# Epoch: 1
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.8714333333333333
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9271
# Epoch: 2
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9371666666666667
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9451
# Epoch: 3
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.95425
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.955
# Epoch: 4
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9625333333333334
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9627
# Epoch: 5
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9698166666666667
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9651
# Epoch: 6
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9734166666666667
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9679
# Epoch: 7
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9771666666666666
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9654
# Epoch: 8
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9803666666666667
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9673
# Epoch: 9
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9824
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9704
# Epoch: 10
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9838166666666667
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9731
# Epoch: 1
# Activation: Tanh(). Loader: train. Accuracy: 0.8857833333333334
# Activation: Tanh(). Loader: valid. Accuracy: 0.9376
# Epoch: 2
# Activation: Tanh(). Loader: train. Accuracy: 0.9450333333333333
# Activation: Tanh(). Loader: valid. Accuracy: 0.9506
# Epoch: 3
# Activation: Tanh(). Loader: train. Accuracy: 0.95975
# Activation: Tanh(). Loader: valid. Accuracy: 0.9599
# Epoch: 4
# Activation: Tanh(). Loader: train. Accuracy: 0.968
# Activation: Tanh(). Loader: valid. Accuracy: 0.9641
# Epoch: 5
# Activation: Tanh(). Loader: train. Accuracy: 0.9729666666666666
# Activation: Tanh(). Loader: valid. Accuracy: 0.966
# Epoch: 6
# Activation: Tanh(). Loader: train. Accuracy: 0.9759166666666667
# Activation: Tanh(). Loader: valid. Accuracy: 0.9654
# Epoch: 7
# Activation: Tanh(). Loader: train. Accuracy: 0.9782333333333333
# Activation: Tanh(). Loader: valid. Accuracy: 0.9679
# Epoch: 8
# Activation: Tanh(). Loader: train. Accuracy: 0.9797833333333333
# Activation: Tanh(). Loader: valid. Accuracy: 0.9679
# Epoch: 9
# Activation: Tanh(). Loader: train. Accuracy: 0.9812
# Activation: Tanh(). Loader: valid. Accuracy: 0.9676
# Epoch: 10
# Activation: Tanh(). Loader: train. Accuracy: 0.9833833333333334
# Activation: Tanh(). Loader: valid. Accuracy: 0.9598
# [0.8854, 0.8998, 0.9008, 0.9018, 0.9014, 0.9012, 0.901, 0.9014, 0.902, 0.9034] [0.9251, 0.9472, 0.958, 0.9612, 0.9642, 0.9661, 0.9672, 0.9665, 0.9664, 0.9675] [0.9271, 0.9451, 0.955, 0.9627, 0.9651, 0.9679, 0.9654, 0.9673, 0.9704, 0.9731] [0.9376, 0.9506, 0.9599, 0.9641, 0.966, 0.9654, 0.9679, 0.9679, 0.9676, 0.9598]

# %% [markdown]
# ### Accuracy
# Построим график accuracy/epoch для каждой функции активации.

# %%
plt.figure(figsize=(16, 10))
plt.title("accuracy")
plt.plot(range(max_epochs), plain_accuracy, label="No activation", linewidth=2)
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(
    range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2
)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.title("accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(
    range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2
)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# **Вопрос 3.** Какая из активаций показала наивысший `accuracy` к концу обучения?
#
# **Ответ:** LeakyReLU
